# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('student-mat.csv')

# %%
df.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
sns.countplot(df['school'])
# Out:
# c:\users\skibi\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <p><b>Korelacja cech z wynikami egzaminów</p></b>

# %%
#Opis uzyskanych wyników dla szkoły GP (egzamin G3)
df[df['school']=='GP']['G3'].describe()
# Out:
# count    315.000000
# mean      11.622222
# std        3.241866
# min        4.000000
# 25%        9.500000
# 50%       11.000000
# 75%       14.000000
# max       20.000000
# Name: G3, dtype: float64

# %%
#Opis uzyskanych wyników dla szkoły MS (egzamin G3)
df[df['school']=='MS']['G3'].describe()
# Out:
# count    42.000000
# mean     10.785714
# std       3.056666
# min       5.000000
# 25%       9.000000
# 50%      10.000000
# 75%      13.000000
# max      19.000000
# Name: G3, dtype: float64

# %%
sns.countplot(df['sex'])
# Out:
# c:\users\skibi\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Opis uzyskanych wyników dla kobiet (egzamin G3)
df[df['sex']=='F']['G3'].describe()
# Out:
# count    185.000000
# mean      11.205405
# std        3.174452
# min        4.000000
# 25%        9.000000
# 50%       11.000000
# 75%       13.000000
# max       19.000000
# Name: G3, dtype: float64

# %%
#Opis uzyskanych wyników dla mężczyzn (egzamin G3)
df[df['sex']=='M']['G3'].describe()
# Out:
# count    172.000000
# mean      11.866279
# std        3.258748
# min        5.000000
# 25%       10.000000
# 50%       12.000000
# 75%       14.000000
# max       20.000000
# Name: G3, dtype: float64

# %%
plt.hist(df['age'], bins=8)
# Out:
# (array([ 82., 104.,  98.,  82.,  24.,   3.,   1.,   1.]),
#  array([15.   , 15.875, 16.75 , 17.625, 18.5  , 19.375, 20.25 , 21.125,
#         22.   ]),
#  <a list of 8 Patch objects>)

# %%
ages_ = list(range(15,23))
ages_
# Out:
# [15, 16, 17, 18, 19, 20, 21, 22]

# %%
mean_scores_by_ages = []
for age_ in ages_:
    mean_scores_by_ages.append(df[df['age']==age_]['G3'].mean())

# %%
len(mean_scores_by_ages)
# Out:
# 8

# %%
#korelacja pomiędzy wiekiem a uzyskaną oceną z egzaminu końcowego (średnia dla danego wieku)
plt.scatter(ages_, mean_scores_by_ages)

# %%
#rozkład wieku ludzi; 20<wiek do odrzucenia 
sns.countplot(df['age'])
# Out:
# c:\users\skibi\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Opis uzyskanych wyników dla miastowych (egzamin G3)
df[df['address']=='U']['G3'].describe()
# Out:
# count    279.000000
# mean      11.745520
# std        3.207978
# min        4.000000
# 25%       10.000000
# 50%       11.000000
# 75%       14.000000
# max       20.000000
# Name: G3, dtype: float64

# %%
#Opis uzyskanych wyników dla wiejskich (egzamin G3)
df[df['address']=='R']['G3'].describe()
# Out:
# count    78.000000
# mean     10.730769
# std       3.193634
# min       5.000000
# 25%       8.250000
# 50%      10.000000
# 75%      12.750000
# max      19.000000
# Name: G3, dtype: float64

# %%
#Opis uzyskanych wyników dla wiejskich (egzamin G3)
df[df['famsize']=='LE3']['G3'].describe()
# Out:
# count    107.000000
# mean      11.719626
# std        3.244137
# min        5.000000
# 25%        9.500000
# 50%       11.000000
# 75%       14.000000
# max       19.000000
# Name: G3, dtype: float64

# %%
#Opis uzyskanych wyników dla wiejskich (egzamin G3)
df[df['famsize']=='GT3']['G3'].describe()
# Out:
# count    250.000000
# mean      11.440000
# std        3.223658
# min        4.000000
# 25%        9.000000
# 50%       11.000000
# 75%       14.000000
# max       20.000000
# Name: G3, dtype: float64

# %%
df[df['G3']==0]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 128     GP   M   18       R     GT3       T     2     2  services     other
# 130     GP   F   15       R     GT3       T     3     4  services   teacher
# 131     GP   F   15       U     GT3       T     1     1   at_home     other
# 134     GP   M   15       R     GT3       T     3     4   at_home   teacher
# 135     GP   F   15       U     GT3       T     4     4  services   at_home
# 136     GP   M   17       R     GT3       T     3     4   at_home     other
# 137     GP   F   16       U     GT3       A     3     3     other     other
# 140     GP   M   15       U     GT3       T     4     3   teacher  services
# 144     GP   M   17       U     GT3       T     2     1     other     other
# 146     GP   F   15       U     GT3       T     3     2    health  services
# 148     GP   M   16       U     GT3       T     4     4   teacher   teacher
# ...

# %%
################

df = df.drop(df[df['G3']<=0].index)

# %%
#Opis uzyskanych wyników dla rodziców żyjących w separacji (egzamin G3)
df[df['Pstatus']=='A']['G3'].describe()
# Out:
# count    39.000000
# mean     11.769231
# std       3.527796
# min       6.000000
# 25%      10.000000
# 50%      11.000000
# 75%      13.500000
# max      19.000000
# Name: G3, dtype: float64

# %%
#Opis uzyskanych wyników dla rodziców żyjących razem (egzamin G3)
df[df['Pstatus']=='T']['G3'].describe()
# Out:
# count    318.000000
# mean      11.493711
# std        3.193787
# min        4.000000
# 25%        9.000000
# 50%       11.000000
# 75%       14.000000
# max       20.000000
# Name: G3, dtype: float64

# %%
medu_ = list(range(5))

mean_scores_by_medu = []
for med_ in medu_:
    mean_scores_by_medu.append(df[df['Medu']==med_]['G3'].mean())

# %%
plt.scatter(medu_, mean_scores_by_medu)

# %%
len(df[df['Medu']==4])
# Out:
# 125

# %%
fedu_ = list(range(5))

mean_scores_by_fedu = []
for fed_ in fedu_:
    mean_scores_by_fedu.append(df[df['Fedu']==fed_]['G3'].mean())

# %%
plt.scatter(fedu_, mean_scores_by_fedu)

# %%
len(df[df['Fedu']==4])
# Out:
# 88

# %%
df[df['Fedu']==0]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob   Fjob  ...  \
# 76      GP   M   15       U     GT3       T     4     0  teacher  other  ...
# 171     GP   M   16       U     GT3       T     1     0    other  other  ...
#
#     famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 76       3        4      3     1     1      1        8  11  11  10
# 171      4        3      2     1     1      3        2  13  15  16
#
# [2 rows x 33 columns]

# %%
df[df['Medu']==0]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 127     GP   F   19       U     GT3       T     0     1  at_home    other
# 249     GP   M   16       U     GT3       T     0     2    other    other
# 324     GP   F   17       U     LE3       T     0     2  at_home  at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 127  ...      3        4      2     1     1      5        2   7   8   9
# 249  ...      4        3      2     2     4      5        0  13  15  15
# 324  ...      3        3      3     2     3      2        0  16  15  15
#
# [3 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
mjobs_ = ['teacher', 'services', 'other']

mean_scores_by_mjob = []
for mjob_ in mjobs_:
    mean_scores_by_mjob.append(df[df['Mjob']==mjob_]['G3'].mean())

# %%
plt.scatter(mjobs_, mean_scores_by_mjob)

# %%
fjobs_ = ['teacher', 'services', 'other']

mean_scores_by_fjob = []
for fjob_ in fjobs_:
    mean_scores_by_fjob.append(df[df['Fjob']==fjob_]['G3'].mean())

# %%
plt.scatter(fjobs_, mean_scores_by_fjob)

# %%
df[(df['Fjob']=='teacher') & (df['Mjob']=='teacher')]['G3'].mean()
# Out:
# 14.272727272727273

# %%
df['G3'].mean()
# Out:
# 11.523809523809524
